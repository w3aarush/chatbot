# %%
import chromadb

# %%
import pandas as pd

# %%
data = pd.read_csv("chatdata.csv")

# %%
data
# Out:
#      Unnamed: 0            user_input          response_msg
# 0             0                    hi                 hello
# 1             1           how are you     fine, how are you
# 2             2                  fine     nice to know this
# 3             3           who are you         I'm a chatbot
# 4             4     where do you live  I live in a computer
# ..          ...                   ...                   ...
# 98           98          nice to know                  good
# 99           99            hw are you                 error
# 100         100             okkkkkkkk                 error
# 101         101                  gret                 error
# 102         102  kya name hai tumhara        My name is Bot
#
# [103 rows x 3 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'user_input', 'response_msg'], dtype='str')

# %%
data.rename(columns={'Unnamed: 0': 'id'}, inplace=True)

# %%
data
# Out:
#       id            user_input          response_msg
# 0      0                    hi                 hello
# 1      1           how are you     fine, how are you
# 2      2                  fine     nice to know this
# 3      3           who are you         I'm a chatbot
# 4      4     where do you live  I live in a computer
# ..   ...                   ...                   ...
# 98    98          nice to know                  good
# 99    99            hw are you                 error
# 100  100             okkkkkkkk                 error
# 101  101                  gret                 error
# 102  102  kya name hai tumhara        My name is Bot
#
# [103 rows x 3 columns]

# %%
data.to_csv("chatdata.csv", index=False)
